# %%
import numpy as np
import matplotlib.pyplot as plt

# Set random seed for reproducibility
np.random.seed(42)

# Simulate 100,000 samples of jointly normal (X, Y) with mean 0, variance 1, and cov = 1/sqrt(2)
mean = [0, 0]
cov = [[1, 1/np.sqrt(2)], [1/np.sqrt(2), 1]]  # Covariance matrix

samples = np.random.multivariate_normal(mean, cov, 100000)
X = samples[:, 0]
Y = samples[:, 1]

# Estimate P(X > 0 | Y < 0)
condition = (Y < 0)
numerator = np.sum((X > 0) & condition)
denominator = np.sum(condition)

conditional_probability = numerator / denominator

# Plotting the region for visual understanding
plt.figure(figsize=(6, 6))
plt.scatter(X[Y < 0], Y[Y < 0], color='lightblue', alpha=0.3, label='Y < 0')
plt.scatter(X[(Y < 0) & (X > 0)], Y[(Y < 0) & (X > 0)], color='red', alpha=0.6, label='X > 0 & Y < 0')
plt.axvline(x=0, color='black', linestyle='--')
plt.axhline(y=0, color='black', linestyle='--')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Red = Region where X > 0 and Y < 0')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
